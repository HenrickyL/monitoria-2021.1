# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
n = np.arange(1,3,0.1)
f = 3*n**2 -n+4
g = 3*n**2

# %%
plt.plot(n,f,'b:o', label='f')
plt.plot(n,g,'y:*', label='c.g')
plt.legend()
